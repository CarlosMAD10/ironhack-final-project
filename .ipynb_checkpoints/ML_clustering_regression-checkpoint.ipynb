# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import pycaret.regression 
import pycaret.clustering
import pycaret.classification
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import BayesianRidge
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.cluster import KMeans
from sklearn.metrics import r2_score
import seaborn as sns
import datetime
from helper_functions import *
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# %matplotlib inline

# %% [markdown]
# # 0. Data import

# %% [markdown]
# We will use the NY Stock Exchange data for training, and the Berlin data for testing. That way we will ensure that the model is useful to be extrapolated to different indexes and stocks.

# %%
data_NY = import_index_data(symbol="NYA")
data_DE = import_index_data(symbol="GDAXI")

# %%
data_NY.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13948 entries, 0 to 13947
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    13948 non-null  datetime64[ns]
#  1   Close   13948 non-null  float64
#  2   Volume  13948 non-null  float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 327.0 KB

# %%
data_train = create_modeling_df(data_NY, 400, snippet_size=20, projection_step=30, scaling ="minmax")
data_test = create_modeling_df(data_DE, 100, snippet_size=20, projection_step=30, scaling ="minmax")

# %%
X_train = data_train.drop(columns=["Pivot_date", "Target_value"])
X_test = data_test.drop(columns=["Pivot_date", "Target_value"])
y_train = data_train["Target_value"]
y_test = data_test["Target_value"]

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (400, 41) (100, 41) (400,) (100,)

# %% [markdown]
# # 1. Trends clustering model

# %% [markdown]
# First we have to drop the final value (pivot value) so the clustering model receives only the normalized trend data.

# %%
X_cluster_train = X_train.drop(columns=["Pivot_value"])
X_cluster_test = X_test.drop(columns=["Pivot_value"])

# %% [markdown]
# We will use custom functions to calculate an elbow and silhouette graph:

# %%
elbow_graph(X_cluster_train)
# Out:
# 0

# %%
silhouette_graph(X_cluster_train)

# %% [markdown]
# We will create 10 clusters, one for each main trend. Next, we will train a model with our training data and visualise the trends that the clustering is trying to capture.

# %%
clustering_model = KMeans(init="k-means++", n_clusters=10)

# %%
#We fit the Kmeans to the training data
clustering_model.fit(X_cluster_train)

#We create the arrays with the predicted clusters, for the training and test data
clusters_train = clustering_model.predict(X_cluster_train)
clusters_test = clustering_model.predict(X_cluster_test)

#We incorporate the clusters to the training and test dataframes, and cast them to objects
X_train["Cluster"] = clusters_train
X_test["Cluster"] = clusters_test
X_train["Cluster"]= X_train["Cluster"].astype(object)
X_test["Cluster"]= X_test["Cluster"].astype(object)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 42 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Vol0         400 non-null    float64
#  1   Vol1         400 non-null    float64
#  2   Vol2         400 non-null    float64
#  3   Vol3         400 non-null    float64
#  4   Vol4         400 non-null    float64
#  5   Vol5         400 non-null    float64
#  6   Vol6         400 non-null    float64
#  7   Vol7         400 non-null    float64
#  8   Vol8         400 non-null    float64
#  9   Vol9         400 non-null    float64
#  10  Vol10        400 non-null    float64
#  11  Vol11        400 non-null    float64
#  12  Vol12        400 non-null    float64
#  13  Vol13        400 non-null    float64
#  14  Vol14        400 non-null    float64
#  15  Vol15        400 non-null    float64
#  16  Vol16        400 non-null    float64
#  17  Vol17        400 non-null    float64
#  18  Vol18        400 non-null    float64
#  19  Vol19        400 non-null    float64
#  20  Close0       400 non-null    float64
#  21  Close1       400 non-null    float64
#  22  Close2       400 non-null    float64
#  23  Close3       400 non-null    float64
#  24  Close4       400 non-null    float64
#  25  Close5       400 non-null    float64
#  26  Close6       400 non-null    float64
#  27  Close7       400 non-null    float64
#  28  Close8       400 non-null    float64
#  29  Close9       400 non-null    float64
#  30  Close10      400 non-null    float64
#  31  Close11      400 non-null    float64
#  32  Close12      400 non-null    float64
#  33  Close13      400 non-null    float64
#  34  Close14      400 non-null    float64
#  35  Close15      400 non-null    float64
#  36  Close16      400 non-null    float64
#  37  Close17      400 non-null    float64
#  38  Close18      400 non-null    float64
#  39  Close19      400 non-null    float64
#  40  Pivot_value  400 non-null    float64
#  41  Cluster      400 non-null    object
# dtypes: float64(41), object(1)
# memory usage: 131.4+ KB

# %% [markdown]
# Now we try to visualise what the clustering model does:
# 1. With a PCA decomposition
# 2. Visualising some trends for each cluster, and see if they seem related.

# %%
visualise_model(X_train, init_algo="k-means++", n_clusters=15, n_init=4)

# %%
visualise_clusters(X_train, n_per_cluster=5)

# %% [markdown]
# # 2. Regression model using clustering results

# %% [markdown]
# Now we will use a tool called Pycaret to study which regression models are more useful. We will have several scenarios:
# 1. Passing all the information, including price, volumes and clusters, as well as pivot value, to the model.
# 2. Only passing the calculated clusters, together with the pivot value.
# 3. Passing the volume information, the calculated clusters, and the pivot value.

# %% [markdown]
# ## 2.1 All the information

# %%
regression_data_1 = X_train.copy()
regression_data_1["Target_value"] = y_train

# %%
regression_data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 43 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Vol0          400 non-null    float64
#  1   Vol1          400 non-null    float64
#  2   Vol2          400 non-null    float64
#  3   Vol3          400 non-null    float64
#  4   Vol4          400 non-null    float64
#  5   Vol5          400 non-null    float64
#  6   Vol6          400 non-null    float64
#  7   Vol7          400 non-null    float64
#  8   Vol8          400 non-null    float64
#  9   Vol9          400 non-null    float64
#  10  Vol10         400 non-null    float64
#  11  Vol11         400 non-null    float64
#  12  Vol12         400 non-null    float64
#  13  Vol13         400 non-null    float64
#  14  Vol14         400 non-null    float64
#  15  Vol15         400 non-null    float64
#  16  Vol16         400 non-null    float64
#  17  Vol17         400 non-null    float64
#  18  Vol18         400 non-null    float64
#  19  Vol19         400 non-null    float64
#  20  Close0        400 non-null    float64
#  21  Close1        400 non-null    float64
#  22  Close2        400 non-null    float64
#  23  Close3        400 non-null    float64
#  24  Close4        400 non-null    float64
#  25  Close5        400 non-null    float64
#  26  Close6        400 non-null    float64
#  27  Close7        400 non-null    float64
#  28  Close8        400 non-null    float64
#  29  Close9        400 non-null    float64
#  30  Close10       400 non-null    float64
#  31  Close11       400 non-null    float64
#  32  Close12       400 non-null    float64
#  33  Close13       400 non-null    float64
#  34  Close14       400 non-null    float64
#  35  Close15       400 non-null    float64
#  36  Close16       400 non-null    float64
#  37  Close17       400 non-null    float64
#  38  Close18       400 non-null    float64
#  39  Close19       400 non-null    float64
#  40  Pivot_value   400 non-null    float64
#  41  Cluster       400 non-null    object
#  42  Target_value  400 non-null    float64
# dtypes: float64(42), object(1)
# memory usage: 134.5+ KB

# %%
reg1 = pycaret.regression.setup(regression_data_1, target = "Target_value", 
                                remove_perfect_collinearity=False) #log_experiment=True, experiment_name='first_trial')
# Out:
# <style type="text/css">
# </style>
# <table id="T_acd83_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_acd83_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_acd83_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_acd83_row0_col1" class="data row0 col1" >776</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_acd83_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_acd83_row1_col1" class="data row1 col1" >Target_value</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_acd83_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_acd83_row2_col1" class="data row2 col1" >(400, 43)</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_acd83_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_acd83_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_acd83_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_acd83_row4_col1" class="data row4 col1" >41</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_acd83_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_acd83_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_acd83_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_acd83_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_acd83_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_acd83_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_acd83_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_acd83_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_acd83_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_acd83_row9_col1" class="data row9 col1" >(279, 56)</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_acd83_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_acd83_row10_col1" class="data row10 col1" >(121, 56)</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_acd83_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_acd83_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_acd83_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_acd83_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_acd83_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_acd83_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_acd83_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_acd83_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_acd83_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_acd83_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_acd83_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_acd83_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_acd83_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_acd83_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_acd83_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_acd83_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_acd83_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_acd83_row19_col1" class="data row19 col1" >7f7b</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_acd83_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_acd83_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_acd83_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_acd83_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_acd83_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_acd83_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_acd83_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_acd83_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_acd83_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_acd83_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_acd83_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_acd83_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_acd83_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_acd83_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_acd83_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_acd83_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_acd83_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_acd83_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_acd83_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_acd83_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_acd83_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_acd83_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_acd83_level0_row31" class="row_heading

# %%
best = pycaret.regression.compare_models()
# Out:
# <style type="text/css">
# #T_fd5ab_ th {
#   text-align: left;
# }
# #T_fd5ab_row0_col0, #T_fd5ab_row0_col5, #T_fd5ab_row1_col0, #T_fd5ab_row1_col1, #T_fd5ab_row1_col2, #T_fd5ab_row1_col3, #T_fd5ab_row1_col4, #T_fd5ab_row1_col6, #T_fd5ab_row2_col0, #T_fd5ab_row2_col1, #T_fd5ab_row2_col2, #T_fd5ab_row2_col3, #T_fd5ab_row2_col4, #T_fd5ab_row2_col6, #T_fd5ab_row3_col0, #T_fd5ab_row3_col1, #T_fd5ab_row3_col2, #T_fd5ab_row3_col3, #T_fd5ab_row3_col4, #T_fd5ab_row3_col5, #T_fd5ab_row3_col6, #T_fd5ab_row4_col0, #T_fd5ab_row4_col1, #T_fd5ab_row4_col2, #T_fd5ab_row4_col3, #T_fd5ab_row4_col4, #T_fd5ab_row4_col5, #T_fd5ab_row4_col6, #T_fd5ab_row5_col0, #T_fd5ab_row5_col1, #T_fd5ab_row5_col2, #T_fd5ab_row5_col3, #T_fd5ab_row5_col4, #T_fd5ab_row5_col5, #T_fd5ab_row5_col6, #T_fd5ab_row6_col0, #T_fd5ab_row6_col1, #T_fd5ab_row6_col2, #T_fd5ab_row6_col3, #T_fd5ab_row6_col4, #T_fd5ab_row6_col5, #T_fd5ab_row6_col6, #T_fd5ab_row7_col0, #T_fd5ab_row7_col1, #T_fd5ab_row7_col2, #T_fd5ab_row7_col3, #T_fd5ab_row7_col4, #T_fd5ab_row7_col5, #T_fd5ab_row7_col6, #T_fd5ab_row8_col0, #T_fd5ab_row8_col1, #T_fd5ab_row8_col2, #T_fd5ab_row8_col3, #T_fd5ab_row8_col4, #T_fd5ab_row8_col5, #T_fd5ab_row8_col6, #T_fd5ab_row9_col0, #T_fd5ab_row9_col1, #T_fd5ab_row9_col2, #T_fd5ab_row9_col3, #T_fd5ab_row9_col4, #T_fd5ab_row9_col5, #T_fd5ab_row9_col6, #T_fd5ab_row10_col0, #T_fd5ab_row10_col1, #T_fd5ab_row10_col2, #T_fd5ab_row10_col3, #T_fd5ab_row10_col4, #T_fd5ab_row10_col5, #T_fd5ab_row10_col6, #T_fd5ab_row11_col0, #T_fd5ab_row11_col1, #T_fd5ab_row11_col2, #T_fd5ab_row11_col3, #T_fd5ab_row11_col4, #T_fd5ab_row11_col5, #T_fd5ab_row11_col6, #T_fd5ab_row12_col0, #T_fd5ab_row12_col1, #T_fd5ab_row12_col2, #T_fd5ab_row12_col3, #T_fd5ab_row12_col4, #T_fd5ab_row12_col5, #T_fd5ab_row12_col6, #T_fd5ab_row13_col0, #T_fd5ab_row13_col1, #T_fd5ab_row13_col2, #T_fd5ab_row13_col3, #T_fd5ab_row13_col4, #T_fd5ab_row13_col5, #T_fd5ab_row13_col6, #T_fd5ab_row14_col0, #T_fd5ab_row14_col1, #T_fd5ab_row14_col2, #T_fd5ab_row14_col3, #T_fd5ab_row14_col4, #T_fd5ab_row14_col5, #T_fd5ab_row14_col6, #T_fd5ab_row15_col0, #T_fd5ab_row15_col1, #T_fd5ab_row15_col2, #T_fd5ab_row15_col3, #T_fd5ab_row15_col4, #T_fd5ab_row15_col5, #T_fd5ab_row15_col6, #T_fd5ab_row16_col0, #T_fd5ab_row16_col1, #T_fd5ab_row16_col2, #T_fd5ab_row16_col3, #T_fd5ab_row16_col4, #T_fd5ab_row16_col5, #T_fd5ab_row16_col6 {
#   text-align: left;
# }
# #T_fd5ab_row0_col1, #T_fd5ab_row0_col2, #T_fd5ab_row0_col3, #T_fd5ab_row0_col4, #T_fd5ab_row0_col6, #T_fd5ab_row1_col5, #T_fd5ab_row2_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_fd5ab_row0_col7, #T_fd5ab_row2_col7, #T_fd5ab_row3_col7, #T_fd5ab_row4_col7, #T_fd5ab_row5_col7, #T_fd5ab_row6_col7, #T_fd5ab_row8_col7, #T_fd5ab_row9_col7, #T_fd5ab_row10_col7, #T_fd5ab_row11_col7, #T_fd5ab_row12_col7, #T_fd5ab_row13_col7, #T_fd5ab_row14_col7, #T_fd5ab_row15_col7, #T_fd5ab_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_fd5ab_row1_col7, #T_fd5ab_row7_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_fd5ab_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd5ab_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_fd5ab_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_fd5ab_row0_col1" class="data row0 col1" >349.3536</td>
#       <td id="T_fd5ab_row0_col2" class="data row0 col2" >229874.7076</td>
#       <td id="T_fd5ab_row0_col3" class="data row0 col3" >467.6377</td>
#       <td id="T_fd5ab_row0_col4" class="data row0 col4" >0.9633</td>
#       <td id="T_fd5ab_row0_col5" class="data row0 col5" >0.0522</td>
#       <td id="T_fd5ab_row0_col6" class="data row0 col6" >0.0403</td>
#       <td id="T_fd5ab_row0_col7" class="data row0 col7" >0.1590</td>
#     </tr>
#     <tr>
#       <th id="T_fd5ab_level0_row1" class="row_heading level0 row1" >br</th>
#       <td id="T_fd5ab_row1_col0" class="data row1 col0" >Bayesian Ridge</td>
#       <td id="T_fd5ab_row1_col1" class="data row1 col1" >357.9117</td>
#       <td id="T_fd5ab_row1_col2" class="data row1 col2" >234521.0822</td>
#       <td id="T_fd5ab_row1_col3" class="data row1 col3" >469.9155</td>
#       <td id="T_fd5ab_row1_col4" class="data row1 col4" >0.9621</td>
#       <td id="T_fd5ab_row1_col5" class="data row1 col5" >0.0516</td>
#       <td id="T_fd5ab_row1_col6" class="data row1 col6" >0.0409</td>
#       <td id="T_fd5ab_row1_col7" class="data row1 col7" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_fd5ab_level0_row2" class="row_heading level0 row2" >en</th>
#       <td id="T_fd5ab_row2_col0" class="data row2 col0" >Elastic Net</td>
#       <td id="T_fd5ab_row2_col1" class="data row2 col1" >360.3413</td>
#       <td id="T_fd5ab_row2_col2" class="data row2 col2" >236831.5945</td>
#       <td id="T_fd5ab_row2_col3" class="data row2 col3" >471.9813</td>
#       <td id="T_fd5ab_row2_col4" class="data row2 col4" >0.9617</td>
#       <td id="T_fd5ab_row2_col5" class="data row2 col5" >0.0516</td>
#       <td id="T_fd5ab_row2_col6" class="data row2 col6" >0.0411</td>
#       <td id="T_fd5ab_row2_col7" class="data row2 col7" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_fd5ab_level0_row3" class="row_heading level0 row3" >llar</th>
#       <td id="T_fd5ab_row3_col0" class="data row3 col0" >Lasso Least Angle Regression</td>
#       <td id="T_fd5ab_row3_col1" class="data row3 col1" >382.8200</td>
#       <td id="T_fd5ab_row3_col2" class="data row3 col2" >252777.6583</td>
#       <td id="T_fd5ab_row3_col3" class="data row3 col3" >489.2185</td>
#       <td id="T_fd5ab_row3_col4" class="data row3 col4" >0.9590</td>
#       <td id="T_fd5ab_row3_col5" class="data row3 col5" >0.0536</td>
#       <td id="T_fd5ab_row3_col6" class="data row3 col6" >0.0436</td>
#       <td id="T_fd5ab_row3_col7" class="data row3 col7" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_fd5ab_level0_row4" class="row_heading level0 row4" >huber</th>
#       <td id="T_fd5ab_row4_col0" class="data row4 col0" >Huber Regressor</td>
#       <td id="T_fd5ab_row4_col1" class="data row4 col1" >368.5261</td>
#       <td id="T_fd5ab_row4_col2" class="data row4 col2" >253867.4244</td>
#       <td id="T_fd5ab_row4_col3" class="data row4 col3" >486.6497</td>
#       <td id="T_fd5ab_row4_col4" class="data row4 col4" >0.9589</td>
#       <td id="T_fd5ab_row4_col5" class="data row4 col5" >0.0535</td>
#       <td id="T_fd5ab_row4_col6" class="data row4 col6" >0.0420</td>
#       <td id="T_fd5ab_row4_col7" class="data row4 col7" >0.0070</td>
#     </tr>
#     <tr>
#       <th id="T_fd5ab_level0_row5" class="row_heading level0 row5" >omp</th>
#       <td id="T_fd5ab_row5_col0" class="data row5 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_fd5ab_row5_col1" class="data row5 col1" >385.2875</td>
#       <td id="T_fd5ab_row5_col2" class="data row5 col2" >257303.5774</td>
#       <td id="T_fd5ab_row5_col3" class="data row5 col3" >494.0567</td>
#       <td id="T_fd5ab_row5_col4" class="data row5 col4" >0.9582</td>
#       <td id="T_fd5ab_row5_col5" class="data row5 col5" >0.0538</td>
#       <td id="T_fd5ab_row5_col6" class="data row5 col6" >0.0438</td>
#       <td id="T_fd5ab_row5_col7" class="data row5 col7" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_fd5ab_level0_row6" class="row_heading level0 row6" >rf</th>
#       <td id="T_fd5ab_row6_col0" class="data row6 col0" >Random Forest Regressor</td>
#       <td id="T_fd5ab_row6_col1" class="data row6 col1" >389.4375</td>
#       <td id="T_fd5ab_row6_col2" class="data row6 col2" >285049.9042</td>
#       <td id="T_fd5ab_row6_col3" class="data row6 col3" >521.379

# %% [markdown]
# Let's analyse the model's results:

# %%
model = pycaret.regression.create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_c54b4_row10_col0, #T_c54b4_row10_col1, #T_c54b4_row10_col2, #T_c54b4_row10_col3, #T_c54b4_row10_col4, #T_c54b4_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_c54b4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c54b4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c54b4_row0_col0" class="data row0 col0" >497.2071</td>
#       <td id="T_c54b4_row0_col1" class="data row0 col1" >660704.0933</td>
#       <td id="T_c54b4_row0_col2" class="data row0 col2" >812.8371</td>
#       <td id="T_c54b4_row0_col3" class="data row0 col3" >0.8726</td>
#       <td id="T_c54b4_row0_col4" class="data row0 col4" >0.0791</td>
#       <td id="T_c54b4_row0_col5" class="data row0 col5" >0.0582</td>
#     </tr>
#     <tr>
#       <th id="T_c54b4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_
td>
#     </tr>
#     <tr>
#       <th id="T_c54b4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c54b4_row8_col0" class="data row8 col0" >595.9053</td>
#       <td id="T_c54b4_row8_col1" class="data row8 col1" >984789.4621</td>
#       <td id="T_c54b4_row8_col2" class="data row8 col2" >992.3656</td>
#       <td id="T_c54b4_row8_col3" class="data row8 col3" >0.8866</td>
#       <td id="T_c54b4_row8_col4" class="data row8 col4" >0.0801</td>
#       <td id="T_c54b4_row8_col5" class="data row8 col5" >0.0553</td>
#     </tr>
#     <tr>
#       <th id="T_c54b4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c54b4_row9_col0" class="data row9 col0" >459.7375</td>
#       <td id="T_c54b4_row9_col1" class="data row9 col1" >351822.3963</td>
#       <td id="T_c54b4_row9_col2" class="data row9 col2" >593.1462</td>
#       <td id="T_c54b4_row9_col3" class="data row9 col3" >0.9303</td>
#       <td id="T_c54b4_row9_col4" class="data row9 col4" >0.0580</td>
#       <td id="T_c54b4_row9_col5" class="data row9 col5" >0.0481</td>
#     </tr>
#     <tr>
#       <th id="T_c54b4_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_c54b4_row10_col0" class="data row10 col0" >451.7429</td>
#       <td id="T_c54b4_row10_col1" class="data row10 col1" >432642.6363</td>
#       <td id="T_c54b4_row10_col2" class="data row10 col2" >632.4454</td>
#       <td id="T_c54b4_row10_col3" class="data row10 col3" >0.9340</td>
#       <td id="T_c54b4_row10_col4" class="data row10 col4" >0.0661</td>
#       <td id="T_c54b4_row10_col5" class="data row10 col5" >0.0507</td>
#     </tr>
#     <tr>
#       <th id="T_c54b4_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_c54b4_row11_col0" class="data row11 col0" >94.1526</td>
#       <td id="T_c54b4_row11_col1" class="data row11 col1" >244361.2368</td>
#       <td id="T_c54b4_row11_col2" class="data row11 col2" >180.7080</td>
#       <td id="T_c54b4_row11_col3" class="data row11 col3" >0.0338</td>
#       <td id="T_c54b4_row11_col4" class="data row11 col4" >0.0104</td>
#       <td id="T_c54b4_row11_col5" class="data row11 col5" >0.0076</td>
#     </tr>
#   </tbody>
# </table>

# %%
pycaret.regression.evaluate_model(model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# We will tune the model's hyperparameters and finalise it, that is, train it with the rest of the NY index data (the training and test data).

# %%
tuned_model = pycaret.regression.tune_model(model)
# Out:
# <style type="text/css">
# #T_cd723_row10_col0, #T_cd723_row10_col1, #T_cd723_row10_col2, #T_cd723_row10_col3, #T_cd723_row10_col4, #T_cd723_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_cd723_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd723_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cd723_row0_col0" class="data row0 col0" >740.9233</td>
#       <td id="T_cd723_row0_col1" class="data row0 col1" >733590.8977</td>
#       <td id="T_cd723_row0_col2" class="data row0 col2" >856.4992</td>
#       <td id="T_cd723_row0_col3" class="data row0 col3" >0.8585</td>
#       <td id="T_cd723_row0_col4" class="data row0 col4" >0.0992</td>
#       <td id="T_cd723_row0_col5" class="data row0 col5" >0.0912</td>
#     </tr>
#     <tr>
#       <th id="T_cd723_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cd723_row1_col0" class="data row1 col0" >781.4811</td>
#       <td id="T_cd723_row1_col1" class="data row1 col1" >899717.6492</td>
#       <td id="T_cd723_row1_col2" class="data row1 col2" >948.5345</td>
#       <td id="T_cd723_row1_col3" class="data row1 col3" >0.8630</td>
#       <td id="T_cd723_row1_col4" class="data row1 col4" >0.1066</td>
#       <td id="T_cd723_row1_col5" class="data row1 col5" >0.0871</td>
#     </tr>
#     <tr>
#       <th id="T_cd723_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c
td>
#     </tr>
#     <tr>
#       <th id="T_cd723_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_cd723_row10_col0" class="data row10 col0" >739.4162</td>
#       <td id="T_cd723_row10_col1" class="data row10 col1" >1041038.9832</td>
#       <td id="T_cd723_row10_col2" class="data row10 col2" >987.1153</td>
#       <td id="T_cd723_row10_col3" class="data row10 col3" >0.8517</td>
#       <td id="T_cd723_row10_col4" class="data row10 col4" >0.1090</td>
#       <td id="T_cd723_row10_col5" class="data row10 col5" >0.0857</td>
#     </tr>
#     <tr>
#       <th id="T_cd723_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_cd723_row11_col0" class="data row11 col0" >178.8917</td>
#       <td id="T_cd723_row11_col1" class="data row11 col1" >541206.9429</td>
#       <td id="T_cd723_row11_col2" class="data row11 col2" >258.1517</td>
#       <td id="T_cd723_row11_col3" class="data row11 col3" >0.0439</td>
#       <td id="T_cd723_row11_col4" class="data row11 col4" >0.0217</td>
#       <td id="T_cd723_row11_col5" class="data row11 col5" >0.0212</td>
#     </tr>
#   </tbody>
# </table>

# %%
final_model = pycaret.regression.finalize_model(tuned_model)

# %% [markdown]
# Now we will use the model to predict the values for the DAX stock information:

# %%
y_test_predict = pycaret.regression.predict_model(final_model, X_test)

# %%
r2_score(y_test, y_test_predict["Label"])
# Out:
# 0.8716842654064729

# %% [markdown]
# ## 2.2 Only cluster information and pivot value

# %%
regression_data_2 = X_train[["Cluster", "Pivot_value"]]
regression_data_2["Target_value"] = y_train

# %%
regression_data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Cluster       400 non-null    object
#  1   Pivot_value   400 non-null    float64
#  2   Target_value  400 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 9.5+ KB

# %%
reg2 = pycaret.regression.setup(regression_data_2, target = "Target_value", 
                                remove_perfect_collinearity=False) #log_experiment=True, experiment_name='first_trial')
# Out:
# <style type="text/css">
# </style>
# <table id="T_99f39_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99f39_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_99f39_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_99f39_row0_col1" class="data row0 col1" >699</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_99f39_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_99f39_row1_col1" class="data row1 col1" >Target_value</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_99f39_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_99f39_row2_col1" class="data row2 col1" >(400, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_99f39_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_99f39_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_99f39_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_99f39_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_99f39_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_99f39_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_99f39_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_99f39_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_99f39_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_99f39_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_99f39_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_99f39_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_99f39_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_99f39_row9_col1" class="data row9 col1" >(279, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_99f39_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_99f39_row10_col1" class="data row10 col1" >(121, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_99f39_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_99f39_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_99f39_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_99f39_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_99f39_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_99f39_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_99f39_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_99f39_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_99f39_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_99f39_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_99f39_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_99f39_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_99f39_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_99f39_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_99f39_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_99f39_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_99f39_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_99f39_row19_col1" class="data row19 col1" >fde7</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_99f39_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_99f39_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_99f39_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_99f39_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_99f39_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_99f39_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_99f39_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_99f39_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_99f39_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_99f39_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_99f39_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_99f39_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_99f39_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_99f39_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_99f39_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_99f39_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_99f39_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_99f39_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_99f39_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_99f39_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_99f39_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_99f39_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_99f39_level0_row31" class="row_heading l

# %%
best_2 = pycaret.regression.compare_models()
# Out:
# <style type="text/css">
# #T_3efb6_ th {
#   text-align: left;
# }
# #T_3efb6_row0_col0, #T_3efb6_row0_col1, #T_3efb6_row0_col2, #T_3efb6_row0_col3, #T_3efb6_row0_col5, #T_3efb6_row0_col6, #T_3efb6_row1_col0, #T_3efb6_row1_col1, #T_3efb6_row1_col6, #T_3efb6_row2_col0, #T_3efb6_row2_col1, #T_3efb6_row2_col2, #T_3efb6_row2_col3, #T_3efb6_row2_col6, #T_3efb6_row3_col0, #T_3efb6_row3_col2, #T_3efb6_row3_col3, #T_3efb6_row3_col4, #T_3efb6_row3_col5, #T_3efb6_row4_col0, #T_3efb6_row4_col1, #T_3efb6_row4_col2, #T_3efb6_row4_col3, #T_3efb6_row4_col4, #T_3efb6_row4_col5, #T_3efb6_row4_col6, #T_3efb6_row5_col0, #T_3efb6_row5_col1, #T_3efb6_row5_col2, #T_3efb6_row5_col3, #T_3efb6_row5_col4, #T_3efb6_row5_col5, #T_3efb6_row5_col6, #T_3efb6_row6_col0, #T_3efb6_row6_col1, #T_3efb6_row6_col2, #T_3efb6_row6_col3, #T_3efb6_row6_col4, #T_3efb6_row6_col5, #T_3efb6_row6_col6, #T_3efb6_row7_col0, #T_3efb6_row7_col1, #T_3efb6_row7_col2, #T_3efb6_row7_col3, #T_3efb6_row7_col4, #T_3efb6_row7_col5, #T_3efb6_row7_col6, #T_3efb6_row8_col0, #T_3efb6_row8_col1, #T_3efb6_row8_col2, #T_3efb6_row8_col3, #T_3efb6_row8_col4, #T_3efb6_row8_col5, #T_3efb6_row8_col6, #T_3efb6_row9_col0, #T_3efb6_row9_col1, #T_3efb6_row9_col2, #T_3efb6_row9_col3, #T_3efb6_row9_col4, #T_3efb6_row9_col5, #T_3efb6_row9_col6, #T_3efb6_row10_col0, #T_3efb6_row10_col1, #T_3efb6_row10_col2, #T_3efb6_row10_col3, #T_3efb6_row10_col4, #T_3efb6_row10_col5, #T_3efb6_row10_col6, #T_3efb6_row11_col0, #T_3efb6_row11_col1, #T_3efb6_row11_col2, #T_3efb6_row11_col3, #T_3efb6_row11_col4, #T_3efb6_row11_col5, #T_3efb6_row11_col6, #T_3efb6_row12_col0, #T_3efb6_row12_col1, #T_3efb6_row12_col2, #T_3efb6_row12_col3, #T_3efb6_row12_col4, #T_3efb6_row12_col5, #T_3efb6_row12_col6, #T_3efb6_row13_col0, #T_3efb6_row13_col1, #T_3efb6_row13_col2, #T_3efb6_row13_col3, #T_3efb6_row13_col4, #T_3efb6_row13_col5, #T_3efb6_row13_col6, #T_3efb6_row14_col0, #T_3efb6_row14_col1, #T_3efb6_row14_col2, #T_3efb6_row14_col3, #T_3efb6_row14_col4, #T_3efb6_row14_col5, #T_3efb6_row14_col6, #T_3efb6_row15_col0, #T_3efb6_row15_col1, #T_3efb6_row15_col2, #T_3efb6_row15_col3, #T_3efb6_row15_col4, #T_3efb6_row15_col5, #T_3efb6_row15_col6, #T_3efb6_row16_col0, #T_3efb6_row16_col1, #T_3efb6_row16_col2, #T_3efb6_row16_col3, #T_3efb6_row16_col4, #T_3efb6_row16_col5, #T_3efb6_row16_col6 {
#   text-align: left;
# }
# #T_3efb6_row0_col4, #T_3efb6_row1_col2, #T_3efb6_row1_col3, #T_3efb6_row1_col4, #T_3efb6_row1_col5, #T_3efb6_row2_col4, #T_3efb6_row2_col5, #T_3efb6_row3_col1, #T_3efb6_row3_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_3efb6_row0_col7, #T_3efb6_row2_col7, #T_3efb6_row5_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T
col7" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_3efb6_level0_row5" class="row_heading level0 row5" >lasso</th>
#       <td id="T_3efb6_row5_col0" class="data row5 col0" >Lasso Regression</td>
#       <td id="T_3efb6_row5_col1" class="data row5 col1" >378.6329</td>
#       <td id="T_3efb6_row5_col2" class="data row5 col2" >268339.0070</td>
#       <td id="T_3efb6_row5_col3" class="data row5 col3" >506.0755</td>
#       <td id="T_3efb6_row5_col4" class="data row5 col4" >0.9593</td>
#       <td id="T_3efb6_row5_col5" class="data row5 col5" >0.0601</td>
#       <td id="T_3efb6_row5_col6" class="data row5 col6" >0.0454</td>
#       <td id="T_3efb6_row5_col7" class="data row5 col7" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_3efb6_level0_row6" class="row_heading level0 row6" >ridge</th>
#       <td id="T_3efb6_row6_col0" class="data row6 col0" >Ridge Regression</td>
#       <td id="T_3efb6_row6_col1" class="data row6 col1" >381.5842</td>
#       <td id="T_3efb6_row6_col2" class="data row6 col2" >270563.3781</td>
#       <td id="T_3efb6_row6_col3" class="data row6 col3" >508.2775</td>

# %%
pycaret.regression.evaluate_model(best_2)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# We tune and finalize the model:

# %%
best_2 = pycaret.regression.tune_model(best_2)
best_2  = pycaret.regression.finalize_model(best_2)
# Out:
# <style type="text/css">
# #T_fcf01_row10_col0, #T_fcf01_row10_col1, #T_fcf01_row10_col2, #T_fcf01_row10_col3, #T_fcf01_row10_col4, #T_fcf01_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_fcf01_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fcf01_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fcf01_row0_col0" class="data row0 col0" >238.7768</td>
#       <td id="T_fcf01_row0_col1" class="data row0 col1" >105535.4297</td>
#       <td id="T_fcf01_row0_col2" class="data row0 col2" >324.8622</td>
#       <td id="T_fcf01_row0_col3" class="data row0 col3" >0.9706</td>
#       <td id="T_fcf01_row0_col4" class="data row0 col4" >0.0329</td>
#       <td id="T_fcf01_row0_col5" class="data row0 col5" >0.0248</td>
#     </tr>
#     <tr>
#       <th id="T_fcf01_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fcf01_row1_col0" class="data row1 col0" >340.7186</td>
#       <td id="T_fcf01_row1_col1" class="data row1 col1" >181996.5000</td>
#       <td id="T_fcf01_row1_col2" class="data row1 col2" >426.6105</td>
#       <td id="T_fcf01_row1_col3" class="data row1 col3" >0.9634</td>
#       <td id="T_fcf01_row1_col4" class="data row1 col4" >0.0526</td>
#       <td id="T_fcf01_row1_col5" class="data row1 col5" >0.0443</td>
#     </tr>
#     <tr>
#       <th id="T_fcf01_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fcf01_row2_col0" class="data row2 col0" >279.1342</td>
#       <td id="T_fcf01_row2_col1" class="data row2 col1" >131869.0625</td>
#       <td id="T_fcf01_row2_col2" class="data row2 col2" >363.1378</td>
#       <td id="T_fcf01_row2_col3" class="data row2 col3" >0.9873</td>
#       <td id="T_fcf01_row2_col4" class="data row2 col4" >0.0583</td>
#       <td id="T_fcf01_row2_col5" class="data row2 col5" >0.0397</td>
#     </tr>
#     <tr>
#       <th id="T_fcf01_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fcf01_row3_col0" class="data row3 col0" >390.3128</td>
#       <td id="T_fcf01_row3_col1" class="data row3 col1" >259625.5312</td>
#       <td id="T_fcf01_row3_col2" class="data row3 col2" >509.5346</td>
#       <td id="T_fcf01_row3_col3" class="data row3 col3" >0.9709</td>
#       <td id="T_fcf01_row3_col4" class="data row3 col4" >0.0612</td>
#       <td id="T_fcf01_row3_col5" class="data row3 col5" >0.0478</td>
#     </tr>
#     <tr>
#       <th id="T_fcf01_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fcf01_row4_col0" class="data row4 col0" >475.7806</td>
#       <td id="T_fcf01_row4_col1" class="data row4 col1" >370048.5000</td>
#       <td id="T_fcf01_row4_col2" class="data row4 col2" >608.3161</td>
#       <td id="T_fcf01_row4_col3" class="data row4 col3" >0.9555</td>
#       <td id="T_fcf01_row4_col4" class="data row4 col4" >0.0589</td>
#       <td id="T_fcf01_row4_col5" class="data row4 col5" >0.0482</td>
#     </tr>
#     <tr>
#       <th id="T_fcf01_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fcf01_row5_col0" class="data row5 col0" >402.9181</td>
#       <td id="T_fcf01_row5_col1" class="data row5 col1" >330599.7188</td>
#       <td id="T_fcf01_row5_col2" class="data row5 col2" >574.9780</td>
#       <td id="T_fcf01_row5_col3" class="data row5 col3" >0.9418</td>
#       <td id="T_fcf01_row5_col4" class="data row5 col4" >0.0656</td>
#       <td id="T_fcf01_row5_col5" class="data row5 col5" >0.0484</td>
#     </tr>
#     <tr>
#       <th id="T_fcf01_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fcf01_row6_col0" class="data row6 col0" >319.5435</td>
#       <td id="T_fcf01_row6_col1" class="data row6 col1" >168761.6719</td>
#       <td id="T_fcf01_row6_col2" class="data row6 col2" >410.8061</td>
#       <td id="T_fcf01_row6_col3" class="data row6 col3" >0.9626</td>
#       <td id="T_fcf01_row6_col4" class="data row6 col4" >0.0451</td>
#       <td id="T_fcf01_row6_col5" class="data row6 col5" >0.0380</td>
#     </tr>
#     <tr>
#       <th id="T_fcf01_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fcf01_row7_col0" class="data row7 col0" >305.6864</td>
#       <td id="T_fcf01_row7_col1" class="data row7 col1" >154321.7031</td>
#       <td id="T_fcf01_row7_col2" class="data row7 col2" >392.8380</td>
#       <td id="T_fcf01_row7_col3" class="data row7 col3" >0.9740</td>
#       <td id="T_fcf01_row7_col4" class="data row7 col4" >0.0470</td>
#       <td id="T_fcf01_row7_col5" class="data row7 col5" >0.0364</td>
#     </tr>
#     <tr>
#       <th id="T_fcf01_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fcf01_row8_col0" class="data row8 col0" >485.0006</td>
#       <td id="T_fcf01_row8_col1" class="data row8 col1" >457910.3438</td>
#       <td id="T_fcf01_row8_col2" class="data row8 col2" >676.6907</td>
#       <td id="T_fcf01_row8_col3" class="data row8 col3" >0.9485</td>
#       <td id="T_fcf01_row8_col4" class="data row8 col4" >0.0677</td>
#       <td id="T_fcf01_row8_col5" class="data row8 col5" >0.0525</td>
#     </tr>
#     <tr>
#       <th id="T_fcf01_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fcf01_row9_col0" class="data row9 col0" >382.3724</td>
#       <td id="T_fcf01_row9_col1" class="data row9 col1" >381260.4688</td>
#       <td id="T_fcf01_row9_col2" class="data row9 col2" >617.4630</td>
#       <td id="T_fcf01_row9_col3" class="data row9 col3" >0.9380</td>
#       <td id="T_fcf01_row9_col4" class="data row9 col4" >0.0856</td>
#       <td id="T_fcf01_row9_col5" class="data row9 col5" >0.0522</td>
#     </tr>
#     <tr>
#       <th id="T_fcf01_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_fcf01_row10_col0" class="data row10 col0" >362.0244</td>
#       <td id="T_fcf01_row10_col1" class="data row10 col1" >254192.8930</td>
#       <td id="T_fcf01_row10_col2" class="data row10 col2" >490.5237</td>
#       <td id="T_fcf01_row10_col3" class="data row10 col3" >0.9613</td>
#       <td id="T_fcf01_row10_col4" class="data row10 col4" >0.0575</td>
#       <td id="T_fcf01_row10_col5" class="data row10 col5" >0.0432</td>
#     </tr>
#     <tr>
#       <th id="T_fcf01_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_fcf01_row11_col0" class="data row11 col0" >76.4483</td>
#       <td id="T_fcf01_row11_col1" class="data row11 col1" >116826.4675</td>
#       <td id="T_fcf01_row11_col2" class="data row11 col2" >116.5307</td>
#       <td id="T_fcf01_row11_col3" class="data row11 col3" >0.0146</td>
#       <td id="T_fcf01_row11_col4" class="data row11 col4" >0.0137</td>
#       <td id="T_fcf01_row11_col5" class="data row11 col5" >0.0082</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Now we try in the data from Berlin

# %%
regression_2_test = X_test[["Cluster", "Pivot_value"]]

# %%
y_predict_2 = pycaret.regression.predict_model(best_2, regression_2_test)

# %%
score_2 = r2_score(y_predict_2["Label"], y_test)
score_2
# Out:
# 0.9536915305576659

# %% [markdown]
# ## 2.3 Volume data and clusters

# %%
regression_data_3 = X_train.iloc[:,0:20]
regression_data_3["Pivot_value"] = X_train["Pivot_value"]
regression_data_3["Cluster"] = X_train["Cluster"]
regression_data_3["Target_value"] = y_train

# %%
reg3 = pycaret.regression.setup(regression_data_3, target = "Target_value", 
                                remove_perfect_collinearity=False) #log_experiment=True, experiment_name='first_trial')
# Out:
# <style type="text/css">
# </style>
# <table id="T_157bb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_157bb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_157bb_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_157bb_row0_col1" class="data row0 col1" >4479</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_157bb_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_157bb_row1_col1" class="data row1 col1" >Target_value</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_157bb_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_157bb_row2_col1" class="data row2 col1" >(400, 23)</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_157bb_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_157bb_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_157bb_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_157bb_row4_col1" class="data row4 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_157bb_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_157bb_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_157bb_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_157bb_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_157bb_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_157bb_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_157bb_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_157bb_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_157bb_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_157bb_row9_col1" class="data row9 col1" >(279, 36)</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_157bb_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_157bb_row10_col1" class="data row10 col1" >(121, 36)</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_157bb_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_157bb_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_157bb_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_157bb_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_157bb_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_157bb_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_157bb_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_157bb_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_157bb_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_157bb_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_157bb_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_157bb_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_157bb_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_157bb_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_157bb_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_157bb_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_157bb_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_157bb_row19_col1" class="data row19 col1" >755e</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_157bb_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_157bb_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_157bb_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_157bb_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_157bb_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_157bb_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_157bb_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_157bb_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_157bb_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_157bb_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_157bb_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_157bb_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_157bb_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_157bb_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_157bb_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_157bb_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_157bb_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_157bb_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_157bb_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_157bb_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_157bb_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_157bb_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_157bb_level0_row31" class="row_headin

# %%
best3 = pycaret.regression.compare_models()
# Out:
# <style type="text/css">
# #T_68d8c_ th {
#   text-align: left;
# }
# #T_68d8c_row0_col0, #T_68d8c_row1_col0, #T_68d8c_row1_col1, #T_68d8c_row1_col2, #T_68d8c_row1_col3, #T_68d8c_row1_col4, #T_68d8c_row1_col5, #T_68d8c_row1_col6, #T_68d8c_row2_col0, #T_68d8c_row2_col1, #T_68d8c_row2_col2, #T_68d8c_row2_col3, #T_68d8c_row2_col4, #T_68d8c_row2_col5, #T_68d8c_row2_col6, #T_68d8c_row3_col0, #T_68d8c_row3_col1, #T_68d8c_row3_col2, #T_68d8c_row3_col3, #T_68d8c_row3_col4, #T_68d8c_row3_col5, #T_68d8c_row3_col6, #T_68d8c_row4_col0, #T_68d8c_row4_col1, #T_68d8c_row4_col2, #T_68d8c_row4_col3, #T_68d8c_row4_col4, #T_68d8c_row4_col5, #T_68d8c_row4_col6, #T_68d8c_row5_col0, #T_68d8c_row5_col1, #T_68d8c_row5_col2, #T_68d8c_row5_col3, #T_68d8c_row5_col4, #T_68d8c_row5_col5, #T_68d8c_row5_col6, #T_68d8c_row6_col0, #T_68d8c_row6_col1, #T_68d8c_row6_col2, #T_68d8c_row6_col3, #T_68d8c_row6_col4, #T_68d8c_row6_col5, #T_68d8c_row6_col6, #T_68d8c_row7_col0, #T_68d8c_row7_col1, #T_68d8c_row7_col2, #T_68d8c_row7_col3, #T_68d8c_row7_col4, #T_68d8c_row7_col5, #T_68d8c_row7_col6, #T_68d8c_row8_col0, #T_68d8c_row8_col1, #T_68d8c_row8_col2, #T_68d8c_row8_col3, #T_68d8c_row8_col4, #T_68d8c_row8_col5, #T_68d8c_row8_col6, #T_68d8c_row9_col0, #T_68d8c_row9_col1, #T_68d8c_row9_col2, #T_68d8c_row9_col3, #T_68d8c_row9_col4, #T_68d8c_row9_col5, #T_68d8c_row9_col6, #T_68d8c_row10_col0, #T_68d8c_row10_col1, #T_68d8c_row10_col2, #T_68d8c_row10_col3, #T_68d8c_row10_col4, #T_68d8c_row10_col5, #T_68d8c_row10_col6, #T_68d8c_row11_col0, #T_68d8c_row11_col1, #T_68d8c_row11_col2, #T_68d8c_row11_col3, #T_68d8c_row11_col4, #T_68d8c_row11_col5, #T_68d8c_row11_col6, #T_68d8c_row12_col0, #T_68d8c_row12_col1, #T_68d8c_row12_col2, #T_68d8c_row12_col3, #T_68d8c_row12_col4, #T_68d8c_row12_col5, #T_68d8c_row12_col6, #T_68d8c_row13_col0, #T_68d8c_row13_col1, #T_68d8c_row13_col2, #T_68d8c_row13_col3, #T_68d8c_row13_col4, #T_68d8c_row13_col5, #T_68d8c_row13_col6, #T_68d8c_row14_col0, #T_68d8c_row14_col1, #T_68d8c_row14_col2, #T_68d8c_row14_col3, #T_68d8c_row14_col4, #T_68d8c_row14_col5, #T_68d8c_row14_col6, #T_68d8c_row15_col0, #T_68d8c_row15_col1, #T_68d8c_row15_col2, #T_68d8c_row15_col3, #T_68d8c_row15_col4, #T_68d8c_row15_col5, #T_68d8c_row15_col6, #T_68d8c_row16_col0, #T_68d8c_row16_col1, #T_68d8c_row16_col2, #T_68d8c_row16_col3, #T_68d8c_row16_col4, #T_68d8c_row16_col5, #T_68d8c_row16_col6 {
#   text-align: left;
# }
# #T_68d8c_row0_col1, #T_68d8c_row0_col2, #T_68d8c_row0_col3, #T_68d8c_row0_col4, #T_68d8c_row0_col5, #T_68d8c_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_68d8c_row0_col7, #T_68d8c_row2_col7, #T_68d8c_row4_col7, #T_68d8c_row6_col7, #T_68d8c_row7_col7, #T_68d8c_row10_col7, #T_68d8c_row11_col7, #T_68d8c_row12_col7, #T_68d8c_row13_col7, #T_68d8c_row15_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_68d8c_row1_col7, #T_68d8c_row3_col7, #T_68d8c_row5_col7, #T_68d8c_row8_col7, #T_68d8c_row9_col7, #T_68d8c_row14_col7, #T_68d8c_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_68d8c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68d8c_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_68d8c_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_68d8c_row0_col1" class="data row0 col1" >325.8660</td>
#       <td id="T_68d8c_row0_col2" class="data row0 col2" >211978.1174</td>
#       <td id="T_68d8c_row0_col3" class="data row0 col3" >452.4665</td>
#       <td id="T_68d8c_row0_col4" class="data row0 col4" >0.9663</td>
#       <td id="T_68d8c_row0_col5" class="data row0 col5" >0.0534</td>
#       <td id="T_68d8c_row0_col6" class="data row0 col6" >0.0387</td>
#       <td id="T_68d8c_row0_col7" class="data row0 col7" >0.1480</td>
#     </tr>
#     <tr>
#       <th id="T
# %%
y_test_predict_3 = pycaret.regression.predict_model(best3, test_data_3)

# %%
score3 = r2_score(y_test_predict_3["Label"], y_test)
score3
# Out:
# 0.889450427604627

# %% [markdown]
# # 3. Adding classification

# %% [markdown]
# The accuracy of the models is very high, and we want to check if changing the goal can make the model more realistic. In order to do so, we will use classification instead of regression. We will try to make the model predict if the index or stock will rise, go down, or trend sideways. We will create five categories using the percentage change between the pivot value and the target value, and then train the model to try and classify using the normalised trends and cluster values.

# %%
X_train["Percentage"] = 100* (y_train - X_train["Pivot_value"])/X_train["Pivot_value"]
X_test["Percentage"] = 100* (y_test - X_test["Pivot_value"])/X_test["Pivot_value"]

# %%
X_train["Percentage"].describe()
# Out:
# count    400.000000
# mean       0.905157
# std        5.537542
# min      -30.418067
# 25%       -2.044627
# 50%        1.582278
# 75%        4.526329
# max       15.399834
# Name: Percentage, dtype: float64

# %%
X_train["Percentage"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### The limits we are going to use are: -3 and 3

# %%
def get_label(x):
    labels = ["Bad", "Neutral", "Good"]
    if x < -3:
        return labels[0]
    elif x < 3:
        return labels[1]
    else:
        return labels[2]

# %%
X_train["Percentage"] = X_train["Percentage"].apply(get_label)
X_test["Percentage"] = X_test["Percentage"].apply(get_label)

# %%
X_train["Percentage"].value_counts()
# Out:
# Neutral    215
# Good       118
# Bad         67
# Name: Percentage, dtype: int64

# %% [markdown]
# Now we will use a classification model and see the results, using:
# 1. All the information
# 2. Only clusters

# %% [markdown]
# ### 3.1 All the information

# %%
class_data_1 = X_train.copy()
class_data_1.drop("Pivot_value", axis=1, inplace=True)

# %%
clf1 = pycaret.classification.setup(class_data_1, target = "Percentage", remove_perfect_collinearity=False)
# Out:
# <style type="text/css">
# </style>
# <table id="T_342ef_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_342ef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_342ef_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_342ef_row0_col1" class="data row0 col1" >4549</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_342ef_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_342ef_row1_col1" class="data row1 col1" >Percentage</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_342ef_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_342ef_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_342ef_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_342ef_row3_col1" class="data row3 col1" >Bad: 0, Good: 1, Neutral: 2</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_342ef_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_342ef_row4_col1" class="data row4 col1" >(400, 42)</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_342ef_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_342ef_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_342ef_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_342ef_row6_col1" class="data row6 col1" >40</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_342ef_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_342ef_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_342ef_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_342ef_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_342ef_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_342ef_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_342ef_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_342ef_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_342ef_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_342ef_row11_col1" class="data row11 col1" >(279, 55)</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_342ef_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_342ef_row12_col1" class="data row12 col1" >(121, 55)</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_342ef_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_342ef_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_342ef_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_342ef_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_342ef_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_342ef_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_342ef_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_342ef_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_342ef_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_342ef_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_342ef_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_342ef_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_342ef_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_342ef_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_342ef_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_342ef_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_342ef_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_342ef_row21_col1" class="data row21 col1" >10df</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_342ef_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_342ef_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_342ef_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_342ef_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_342ef_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_342ef_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_342ef_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_342ef_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_342ef_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_342ef_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_342ef_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_342ef_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_342ef_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_342ef_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_342ef_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_342ef_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_342ef_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_342ef_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_342ef_level0

# %%
best_class = pycaret.classification.compare_models()
# Out:
# <style type="text/css">
# #T_7cfd0_ th {
#   text-align: left;
# }
# #T_7cfd0_row0_col0, #T_7cfd0_row0_col2, #T_7cfd0_row0_col4, #T_7cfd0_row0_col5, #T_7cfd0_row1_col0, #T_7cfd0_row1_col1, #T_7cfd0_row1_col2, #T_7cfd0_row1_col3, #T_7cfd0_row1_col6, #T_7cfd0_row1_col7, #T_7cfd0_row2_col0, #T_7cfd0_row2_col1, #T_7cfd0_row2_col2, #T_7cfd0_row2_col3, #T_7cfd0_row2_col4, #T_7cfd0_row2_col5, #T_7cfd0_row2_col6, #T_7cfd0_row2_col7, #T_7cfd0_row3_col0, #T_7cfd0_row3_col1, #T_7cfd0_row3_col3, #T_7cfd0_row3_col4, #T_7cfd0_row3_col5, #T_7cfd0_row3_col6, #T_7cfd0_row3_col7, #T_7cfd0_row4_col0, #T_7cfd0_row4_col1, #T_7cfd0_row4_col2, #T_7cfd0_row4_col3, #T_7cfd0_row4_col4, #T_7cfd0_row4_col5, #T_7cfd0_row4_col6, #T_7cfd0_row4_col7, #T_7cfd0_row5_col0, #T_7cfd0_row5_col1, #T_7cfd0_row5_col2, #T_7cfd0_row5_col3, #T_7cfd0_row5_col4, #T_7cfd0_row5_col5, #T_7cfd0_row5_col6, #T_7cfd0_row5_col7, #T_7cfd0_row6_col0, #T_7cfd0_row6_col1, #T_7cfd0_row6_col2, #T_7cfd0_row6_col3, #T_7cfd0_row6_col4, #T_7cfd0_row6_col5, #T_7cfd0_row6_col6, #T_7cfd0_row6_col7, #T_7cfd0_row7_col0, #T_7cfd0_row7_col1, #T_7cfd0_row7_col2, #T_7cfd0_row7_col3, #T_7cfd0_row7_col4, #T_7cfd0_row7_col5, #T_7cfd0_row7_col6, #T_7cfd0_row7_col7, #T_7cfd0_row8_col0, #T_7cfd0_row8_col1, #T_7cfd0_row8_col2, #T_7cfd0_row8_col3, #T_7cfd0_row8_col4, #T_7cfd0_row8_col5, #T_7cfd0_row8_col6, #T_7cfd0_row8_col7, #T_7cfd0_row9_col0, #T_7cfd0_row9_col1, #T_7cfd0_row9_col2, #T_7cfd0_row9_col3, #T_7cfd0_row9_col4, #T_7cfd0_row9_col5, #T_7cfd0_row9_col6, #T_7cfd0_row9_col7, #T_7cfd0_row10_col0, #T_7cfd0_row10_col1, #T_7cfd0_row10_col2, #T_7cfd0_row10_col3, #T_7cfd0_row10_col4, #T_7cfd0_row10_col5, #T_7cfd0_row10_col6, #T_7cfd0_row10_col7, #T_7cfd0_row11_col0, #T_7cfd0_row11_col1, #T_7cfd0_row11_col2, #T_7cfd0_row11_col3, #T_7cfd0_row11_col4, #T_7cfd0_row11_col5, #T_7cfd0_row11_col6, #T_7cfd0_row11_col7, #T_7cfd0_row12_col0, #T_7cfd0_row12_col1, #T_7cfd0_row12_col2, #T_7cfd0_row12_col3, #T_7cfd0_row12_col4, #T_7cfd0_row12_col5, #T_7cfd0_row12_col6, #T_7cfd0_row12_col7 {
#   text-align: left;
# }
# #T_7cfd0_row0_col1, #T_7cfd0_row0_col3, #T_7cfd0_row0_col6, #T_7cfd0_row0_col7, #T_7cfd0_row1_col4, #T_7cfd0_row1_col5, #T_7cfd0_row3_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_
col8" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_7cfd0_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_7cfd0_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_7cfd0_row5_col1" class="data row5 col1" >0.4873</td>
#       <td id="T_7cfd0_row5_col2" class="data row5 col2" >0.5427</td>
#       <td id="T_7cfd0_row5_col3" class="data row5 col3" >0.3571</td>
#       <td id="T_7cfd0_row5_col4" class="data row5 col4" >0.4340</td>
#       <td id="T_7cfd0_row5_col5" class="data row5 col5" >0.4436</td>
#       <td id="T_7cfd0_row5_col6" class="data row5 col6" >0.0463</td>
#       <td id="T_7cfd0_row5_col7" class="data row5 col7" >0.0475</td>
#       <td id="T_7cfd0_row5_col8" class="data row5 col8" >0.0240</td>
#     </tr>
#     <tr>
#       <th id="T_7cfd0_level0_row6" class="row_heading level0 row6" >gbc</th>
#       <td id="T_7cfd0_row6_col0" class="data row6 col0" >Gradient Boosting Classifier</td>
#       <td id="T_7cfd0_row6_col1" class="data row6 col1" >0.4694</td>
#       <td id="T_7cfd0_row6_col2" class="data row6 col2" >0.5164</td>
#       <td id="T_7cfd0_r

# %%
pycaret.classification.plot_model(best_class)

# %%
pycaret.classification.evaluate_model(best_class)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# ### 3.2 Only clustering information

# %%
class_data_2 = X_train[["Cluster", "Percentage"]]

# %%
clf2 = pycaret.classification.setup(class_data_2, target = "Percentage", remove_perfect_collinearity=False)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a83f1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a83f1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a83f1_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_a83f1_row0_col1" class="data row0 col1" >8741</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a83f1_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a83f1_row1_col1" class="data row1 col1" >Percentage</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a83f1_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_a83f1_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a83f1_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_a83f1_row3_col1" class="data row3 col1" >Bad: 0, Good: 1, Neutral: 2</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a83f1_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_a83f1_row4_col1" class="data row4 col1" >(400, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a83f1_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_a83f1_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a83f1_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_a83f1_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a83f1_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_a83f1_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a83f1_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_a83f1_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a83f1_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_a83f1_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a83f1_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_a83f1_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a83f1_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_a83f1_row11_col1" class="data row11 col1" >(279, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a83f1_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_a83f1_row12_col1" class="data row12 col1" >(121, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a83f1_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_a83f1_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a83f1_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_a83f1_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a83f1_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_a83f1_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a83f1_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_a83f1_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a83f1_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_a83f1_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a83f1_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_a83f1_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a83f1_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_a83f1_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a83f1_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_a83f1_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_a83f1_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_a83f1_row21_col1" class="data row21 col1" >df96</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_a83f1_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_a83f1_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_a83f1_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_a83f1_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_a83f1_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_a83f1_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_a83f1_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_a83f1_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_a83f1_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_a83f1_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_a83f1_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_a83f1_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_a83f1_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_a83f1_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_a83f1_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_a83f1_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_a83f1_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_a83f1_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a83f1_level0_r

# %%
best_class_2 = pycaret.classification.compare_models()
# Out:
# <style type="text/css">
# #T_d042e_ th {
#   text-align: left;
# }
# #T_d042e_row0_col0, #T_d042e_row0_col2, #T_d042e_row0_col3, #T_d042e_row0_col4, #T_d042e_row0_col5, #T_d042e_row0_col6, #T_d042e_row0_col7, #T_d042e_row1_col0, #T_d042e_row1_col1, #T_d042e_row1_col3, #T_d042e_row1_col4, #T_d042e_row2_col0, #T_d042e_row2_col1, #T_d042e_row2_col2, #T_d042e_row2_col3, #T_d042e_row2_col4, #T_d042e_row2_col5, #T_d042e_row2_col6, #T_d042e_row2_col7, #T_d042e_row3_col0, #T_d042e_row3_col1, #T_d042e_row3_col2, #T_d042e_row3_col3, #T_d042e_row3_col4, #T_d042e_row3_col5, #T_d042e_row3_col6, #T_d042e_row3_col7, #T_d042e_row4_col0, #T_d042e_row4_col1, #T_d042e_row4_col2, #T_d042e_row4_col3, #T_d042e_row4_col4, #T_d042e_row4_col5, #T_d042e_row4_col6, #T_d042e_row4_col7, #T_d042e_row5_col0, #T_d042e_row5_col1, #T_d042e_row5_col2, #T_d042e_row5_col3, #T_d042e_row5_col4, #T_d042e_row5_col5, #T_d042e_row5_col6, #T_d042e_row5_col7, #T_d042e_row6_col0, #T_d042e_row6_col1, #T_d042e_row6_col2, #T_d042e_row6_col3, #T_d042e_row6_col4, #T_d042e_row6_col5, #T_d042e_row6_col6, #T_d042e_row6_col7, #T_d042e_row7_col0, #T_d042e_row7_col1, #T_d042e_row7_col2, #T_d042e_row7_col3, #T_d042e_row7_col4, #T_d042e_row7_col5, #T_d042e_row7_col6, #T_d042e_row7_col7, #T_d042e_row8_col0, #T_d042e_row8_col1, #T_d042e_row8_col2, #T_d042e_row8_col3, #T_d042e_row8_col4, #T_d042e_row8_col5, #T_d042e_row8_col6, #T_d042e_row8_col7, #T_d042e_row9_col0, #T_d042e_row9_col1, #T_d042e_row9_col2, #T_d042e_row9_col3, #T_d042e_row9_col4, #T_d042e_row9_col5, #T_d042e_row9_col6, #T_d042e_row9_col7, #T_d042e_row10_col0, #T_d042e_row10_col1, #T_d042e_row10_col2, #T_d042e_row10_col3, #T_d042e_row10_col4, #T_d042e_row10_col5, #T_d042e_row10_col6, #T_d042e_row10_col7, #T_d042e_row11_col0, #T_d042e_row11_col1, #T_d042e_row11_col2, #T_d042e_row11_col4, #T_d042e_row11_col5, #T_d042e_row11_col6, #T_d042e_row11_col7, #T_d042e_row12_col0, #T_d042e_row12_col1, #T_d042e_row12_col2, #T_d042e_row12_col3, #T_d042e_row12_col5, #T_d042e_row12_col6, #T_d042e_row12_col7 {
#   text-align: left;
# }
# #T_d042e_row0_col1, #T_d042e_row1_col2, #T_d042e_row1_col5, #T_d042e_row1_col6, #T_d042e_row1_col7, #T_d042e_row11_col3, #T_d042e_row12_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d042e_row0_col8, #T_d042e_row1_col8, #T_d042e_row2_col8, #T_d042e_row4_col8, #T_d042e_row6_col8, #T_d042e_row7_col8, #T_d042e_row9_col8, #T_d042e_row10_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_d042e_row3_col8, #T_d042e_row5_col8, #T_d042e_row8_col8, #T_d042e_row11_col8, #T_d042e_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d042e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d042e_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_d042e_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_d042e_row0_col1" class="data row0 col1" >0.5376</td>
#       <td id="T_d042e_row0_col2" class="data row0 col2" >0.5006</td>
#       <td id="T_d042e_row0_col3" class="data row0 col3" >0.3491</td>
#       <td id="T_d042e_row0_col4" class="data row0 col4" >0.4269</td>
#       <td id="T_d042e_row0_col5" class="data row0 col5" >0.4169</td>
#       <td id="T_d042e_row0_col6" class="data row0 col6" >0.0373</td>
#       <td id="T_d042e_row0_col7" class="data row0 col7" >0.0651</td>
#       <td id="T_d042e_row0_col8" class="data row0 col8" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_d042e_level0_row1" class="row_heading level0 row1" >ada</th>
#       <td id="T_d042e_row1_col0" class="data row1 col0" >Ada Boost Classifier</td>
#       <td id="T_d042e_row1_col1" class="data row1 col1" >0.5339</td>
#       <td id="T_d042e_row1_col2" class="data row1 col2" >0.5733</td>
#       <td id="T_d042e_row1_col3" class="data row1 col3" >0.3793</td>
#       <td id="T_d042e_row1_col4" class="data row1 col4" >0.4592</td>
#       <td id="T_d042e_row1_col5" class="data row1 col5" >0.4669</td>
#       <td id="T_d042e_row1_col6" class="data row1 col6" >0.0979</td>
#       <td id="T_d042e_row1_col7" class="data row1 col7" >0.1244</td>
#       <td id="T_d042e_row1_col8" class="data row1 col8" >0.0250</td>
#     </tr>
#     <tr>
#       <th id="T_d042e_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_d042e_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_d042e_row2_col1" class="data row2 col1" >0.5267</td>
#       <td id="T_d042e_row2_col2" class="data row2 col2" >0.5643</td>
#       <td id="T_d042e_row2_col3" class="data row2 col3" >0.3719</td>
#       <td id="T_d042e_row2_col4" class="data row2 col4" >0.4488</td>
#       <td id="T_d042e_row2_col5" class="data row2 col5" >0.4572</td>
#       <td id="T_d042e_row2_col6" class="data row2 col6" >0.0807</td>
#       <td id="T_d042e_row2_col7" class="data row2 col7" >0.1034</td>
#       <td id="T_d042e_row2_col8" class="data row2 col8" >0.0330</td>
#     </tr>
#     <tr>
#       <th id="T_d042e_level0_row3" class="row_heading level0 row3" >dt</th>
#       <td id="T_d042e_row3_col0" class="data row3 col0" >Decision Tree Classifier</td>
#       <td id="T_d042e_row3_col1" class="data row3 col1" >0.5231</td>
#       <td id="T_d042e_row3_col2" class="data row3 col2" >0.5640</td>
#       <td id="T_d042e_row3_col3" class="data row3 col3" >0.3784</td>
#       <td id="T_d042e_row3_col4" class="data row3 col4" >0.4525</td>
#       <td id="T_d042e_row3_col5" class="data row3 col5" >0.4606</td>
#       <td id="T_d042e_row3_col6" class="data row3 col6" >0.0908</td>
#       <td id="T_d042e_row3_col7" class="data row3 col7" >0.1151</td>
#       <td id="T_d042e_row3_col8" class="data row3 col8" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_d042e_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_d042e_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_d042e_row4_col1" class="data row4 col1" >0.5231</td>
#       <td id="T_d042e_row4_col2" class="data row4 col2" >0.5637</td>
#       <td id="T_d042e_row4_col3" class="data row4 col3" >0.3671</td>
#       <td id="T_d042e_row4_col4" class="data row4 col4" >0.4372</td>
#       <td id="T_d042e_row4_col5" class="data row4 col5" >0.4487</td>
#       <td id="T_d042e_row4_col6" class="data row4 col6" >0.0673</td>
#       <td id="T_d042e_row4_col7" class="data row4 col7" >0.0855</td>
#       <td id="T_d042e_row4_col8" class="data row4 col8" >0.1730</td>
#     </tr>
#     <tr>
#       <th id="T_d042e_level0_row5" class="row_heading level0 row5" >lda</th>
#       <td id="T_d042e_row5_col0" class="data row5 col0" >Linear Discriminant Analysis</td>
#       <td id="T_d042e_row5_col1" class="data row5 col1" >0.5231</td>
#       <td id="T_d042e_row5_col2" class="data row5 col2" >0.5611</td>
#       <td id="T_d042e_row5_col3" class="data row5 col3" >0.3701</td>
#       <td id="T_d042e_row5_col4" class="data row5 col4" >0.4516</td>
#       <td id="T_d042e_row5_col5" class="data row5 col5" >0.4572</td>
#       <td id="T_d042e_row5_col6" class="data row5 col6" >0.0825</td>
#       <td id="T_d042e_row5_col7" class="data row5 col7" >0.1035</td>
#       <td id="T_d042e_row5_col8" class="data row5 col8" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_d042e_level0_row6" class="row_heading level0 row6" >et</th>
#       <td id="T_d042e_row6_col0" class="data row6 col0" >Extra Trees Classifier</td>
#       <td id="T_d042e_row6_col1" class="data row6 col1" >0.5231</td>
#       <td id="T_d042e_row6_col2" class="data row6 col2" >0.5640</td>
#       <td id="T_d04

# %%
pycaret.classification.evaluate_model(best_class_2)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…
