# %%
import numpy as np
import pandas as pd
from helper_functions import *
import matplotlib.pyplot as plt
from modeling_program import *
#%matplotlib inline

# %%
setup_train = {"number_of_snippets": 200, "previous_days":800, "snippet_size":30,
                 "projection_step":20, "scaling":"minmax", "n_clusters":10}

setup_test = {"number_of_snippets":20, "previous_days":400, "snippet_size":30,
         "projection_step":20, "scaling":"minmax", "n_clusters":10}

list_of_indexes = ['NYA', 'IXIC', 'HSI', 'GSPTSE', 'NSEI',
         'KS11', 'SSMI', 'TWII',  'N225', 'N100']

test_index = ["GDAXI"]

create_models(setup_data=setup_train, list_of_indexes=list_of_indexes)
# Out:
# <style type="text/css">
# #T_a9956_row10_col0, #T_a9956_row10_col1, #T_a9956_row10_col2, #T_a9956_row10_col3, #T_a9956_row10_col4, #T_a9956_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_a9956_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9956_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a9956_row0_col0" class="data row0 col0" >393.6419</td>
#       <td id="T_a9956_row0_col1" class="data row0 col1" >477770.1338</td>
#       <td id="T_a9956_row0_col2" class="data row0 col2" >691.2092</td>
# ...

# %%
clustering, classification, regression = load_models(path_cluster="clustering_model.pkl", path_class="classification_model",
        path_reg="regression_model")
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Transformation Pipeline and Model Successfully Loaded

# %%
 y_test, y_pred, X = evaluation_ccr(clustering, classification, regression, 
        data=None, setup_data=setup_test, indexes=test_index)
# Out:
# The R2 score for the prediction is 0.594. Its accuracy based on the Mean Absolute error is 93.907 %
